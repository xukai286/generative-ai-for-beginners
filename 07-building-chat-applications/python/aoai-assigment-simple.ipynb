# %%
import os
import openai
import dotenv

from openai import AzureOpenAI

dotenv.load_dotenv("/etc/.env")

# openai.api_type = "azure"
openai.api_version = os.getenv("AZURE_OPENAI_API_VERSION","").strip()

API_KEY = os.getenv("AZURE_OPENAI_API_KEY","").strip()
assert API_KEY, "ERROR: Azure OpenAI Key is missing"
openai.api_key = API_KEY

RESOURCE_ENDPOINT = os.getenv("OPENAI_API_BASE","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
openai.api_base = RESOURCE_ENDPOINT
deployment = "gpt-4o" # replace with your deployment name

client = AzureOpenAI(
  azure_endpoint = openai.api_base,
  api_key=openai.api_key,  
  api_version = "2025-03-01-preview"
  )

# %%
# Create your first prompt
text_prompt = " My foot hurts, what can be wrong?"

completion = client.chat.completions.create(
  model=deployment,
  messages=[
    {"role":"system", "content":"I'm a doctor, specialist on surgery"},
    {"role":"user","content":text_prompt},
  ],
  # max_tokens=100,
  temperature=0.7,
)

completion.choices[0].message.content

# Uncomment the following lines to use the OpenAI API directly
# response = openai.ChatCompletion.create(
#   engine=deployment,
#   messages = [
#       {"role":"system", "content":"I'm a doctor, specialist on surgery"},
#       {"role":"user","content":text_prompt},])


# response['choices'][0]['message']['content']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Create your first prompt
#       2 text_prompt = " My foot hurts, what can be wrong?"
# ----> 4 completion = client.chat.completions.create(
#       5   deployment_id=deployment,
#       6   messages=[
#       7     {"role":"system", "content":"I'm a doctor, specialist on surgery"},
#       8     {"role":"user","content":text_prompt},
#       9   ],
#      10   # max_tokens=100,
#      11   temperature=0.7,
#      12 )
#      14 completion.choices[0].message.content
#
# File ~/anaconda3/envs/ai4beg/lib/python3.10/site-packages/openai/_utils/_utils.py:278, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             msg = f"Missing required argument: {quote(missing[0])}"
# --> 278     raise TypeError(msg)
#     279 return func(*args, **kwargs)
#
# TypeError: Missing required arguments; Expected either ('messages' and 'model') or ('messages', 'model' and 'stream') arguments to be given
